# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Ice Cream Sales - temperatures.csv')

# %%
df
# Out:
#      Temperature  Ice Cream Profits
# 0             39              13.17
# 1             40              11.88
# 2             41              18.82
# 3             42              18.65
# 4             43              17.02
# ..           ...                ...
# 360           99              85.13
# 361           99              87.08
# 362           99              89.29
# 363          101              81.91
# 364          101              85.02
#
# [365 rows x 2 columns]

# %%
df.rename(columns = {'Ice Cream Profits':'Profits'},inplace = True)

# %%
df.head()
# Out:
#    Temperature  Profits
# 0           39    13.17
# 1           40    11.88
# 2           41    18.82
# 3           42    18.65
# 4           43    17.02

# %%
plt.scatter(df.Temperature , df.Profits)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  365 non-null    int64
#  1   Profits      365 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 5.8 KB

# %%
df.describe()
# Out:
#        Temperature     Profits
# count   365.000000  365.000000
# mean     71.980822   52.103616
# std      13.258510   15.989004
# min      39.000000   11.880000
# 25%      63.000000   40.650000
# 50%      73.000000   53.620000
# 75%      82.000000   63.630000
# max     101.000000   89.290000

# %%
df.isna().sum()
# Out:
# Temperature    0
# Profits        0
# dtype: int64

# %%
df.shape
# Out:
# (365, 2)

# %% [markdown]
# ####  NOW DEVIDE THE DATASET INTO DEPENDENT AND INDEPENDENT FEATURE

# %%
x = df[['Temperature']]
y = df['Profits']

# %%
x.shape , y.shape
# Out:
# ((365, 1), (365,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split( x , y , test_size = 0.25 , random_state = 15)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((273, 1), (92, 1), (273,), (92,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.73598571],
#        [-0.96801661],
#        [-0.07897192],
#        [-0.96801661],
#        [-0.67166838],
#        [-0.15305898],
#        [ 1.47685629],
#        [ 0.88415983],
#        [ 0.51372454],
#        [-0.59758132],
#        [-0.59758132],
#        [ 1.40276923],
#        [-2.22749658],
#        [-0.07897192],
#        [-0.22714603],
#        [ 0.43963748],
#        [ 1.6250304 ],
#        [-0.59758132],
#        [-1.04210367],
#        [ 0.21737631],
#        [ 0.21737631],
#        [-0.30123309],
#        [ 1.77320452],
#        [ 0.14328925],
#        [ 0.73598571],
#        [ 0.0692022 ],
#        [ 1.03233394],
#        [ 0.73598571],
#        [ 0.14328925],
#        [-1.8570613 ],
#        [-0.30123309],
#        [-1.48662601],
#        [-0.81984249],
#        [-0.37532015],
#        [-2.07932247],
#        [-2.00523541],
#        [-0.22714603],
#        [ 0.14328925],
#        [ 1.47685629],
#        [ 0.66189866],
#        [-0.59758132],
# ...

# %%
x_test
# Out:
# array([[-0.74575544],
#        [ 1.47685629],
#        [-0.81984249],
#        [ 0.88415983],
#        [ 0.95824689],
#        [-2.30158364],
#        [-0.44940721],
#        [-0.30123309],
#        [-1.63480012],
#        [ 1.99546569],
#        [ 1.40276923],
#        [ 0.21737631],
#        [-0.07897192],
#        [-0.59758132],
#        [ 0.36555043],
#        [-1.33845189],
#        [-0.96801661],
#        [-1.04210367],
#        [ 0.29146337],
#        [ 1.32868217],
#        [ 0.29146337],
#        [-0.59758132],
#        [ 1.69911746],
#        [-0.15305898],
#        [-0.37532015],
#        [ 1.18050806],
#        [ 0.29146337],
#        [ 0.95824689],
#        [-1.78297424],
#        [ 0.5878116 ],
#        [ 0.95824689],
#        [ 0.95824689],
#        [ 0.73598571],
#        [-1.48662601],
#        [ 0.14328925],
#        [-0.74575544],
#        [ 1.25459512],
#        [-0.07897192],
#        [-2.07932247],
#        [ 0.36555043],
#        [ 0.0692022 ],
# ...

# %%
plt.scatter(x_train , y_train)

# %% [markdown]
# ## MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %% [markdown]
# TRAINING THE MODEL WITH THE TRAIN DATA

# %%
regressor.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
regressor.intercept_
# Out:
# 52.16908424908426

# %%
regressor.coef_
# Out:
# array([15.99438792])

# %% [markdown]
# #### BEST FIT LINE

# %%
plt.scatter(x_train , y_train)
plt.plot(x_train , regressor.predict(x_train),'r')

# %% [markdown]
# PREDICTION

# %%
x_test
# Out:
# array([[-0.74575544],
#        [ 1.47685629],
#        [-0.81984249],
#        [ 0.88415983],
#        [ 0.95824689],
#        [-2.30158364],
#        [-0.44940721],
#        [-0.30123309],
#        [-1.63480012],
#        [ 1.99546569],
#        [ 1.40276923],
#        [ 0.21737631],
#        [-0.07897192],
#        [-0.59758132],
#        [ 0.36555043],
#        [-1.33845189],
#        [-0.96801661],
#        [-1.04210367],
#        [ 0.29146337],
#        [ 1.32868217],
#        [ 0.29146337],
#        [-0.59758132],
#        [ 1.69911746],
#        [-0.15305898],
#        [-0.37532015],
#        [ 1.18050806],
#        [ 0.29146337],
#        [ 0.95824689],
#        [-1.78297424],
#        [ 0.5878116 ],
#        [ 0.95824689],
#        [ 0.95824689],
#        [ 0.73598571],
#        [-1.48662601],
#        [ 0.14328925],
#        [-0.74575544],
#        [ 1.25459512],
#        [-0.07897192],
#        [-2.07932247],
#        [ 0.36555043],
#        [ 0.0692022 ],
# ...

# %%
xt_pred_test = regressor.predict(x_train)

# %%
y_pred_test = regressor.predict(x_test)

# %%
y_pred_test
# Out:
# array([40.24118252, 75.79049662, 39.05620538, 66.31067953, 67.49565667,
#        15.35666265, 44.98109107, 47.35104534, 26.02145688, 84.08533658,
#        74.60551949, 55.6458853 , 50.90597675, 42.61113679, 58.01583957,
#        30.76136543, 36.68625111, 35.50127397, 56.83086244, 73.42054235,
#        56.83086244, 42.61113679, 79.34542803, 49.72099961, 46.1660682 ,
#        71.05058808, 56.83086244, 67.49565667, 23.65150261, 61.57077098,
#        67.49565667, 67.49565667, 63.94072526, 28.39141115, 54.46090816,
#        40.24118252, 72.23556521, 50.90597675, 18.91159406, 58.01583957,
#        53.27593103, 44.98109107, 65.12570239, 58.01583957, 62.75574812,
#        52.09095389, 66.31067953, 34.31629684, 58.01583957, 49.72099961,
#        37.87122825, 31.94634256, 63.94072526, 53.27593103, 58.01583957,
#        62.75574812, 36.68625111, 47.35104534, 46.1660682 , 24.83647974,
#        54.46090816, 48.53602248, 58.01583957, 43.79611393, 43.79611393,
# ...

# %%
y_test
# Out:
# 83     39.04
# 346    77.41
# 80     39.42
# 298    67.58
# 307    62.99
#        ...
# 251    57.44
# 109    42.71
# 176    52.13
# 206    59.69
# 320    70.43
# Name: Profits, Length: 92, dtype: float64

# %% [markdown]
# ## PERFORMANCE METRICS - MAE , MSE , RMSE

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred_test)
mae = mean_absolute_error(y_test,y_pred_test)
rmse = np.sqrt(mse)

# %%
print(mse)
print(mae)
print(rmse)
# Out:
# 5.518977755913755
# 1.886715529977912
# 2.3492504668327205

# %% [markdown]
# ## ACCURACY OF THE MODEL

# %%
from sklearn.metrics import r2_score

# %%
trainscore = r2_score(y_train , xt_pred_test)
trainscore
# Out:
# 0.977140390928095

# %%
score = r2_score(y_test , y_pred_test)
score
# Out:
# 0.9764698187713102

# %% [markdown]
# ### ADJUSTED R SQUERE

# %%
1-(1-score)*(len(y_test -1))/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.9759469258551171

# %%
regressor
# Out:
# LinearRegression()

# %%
scaler
# Out:
# StandardScaler()

# %% [markdown]
# #### RANDOM PREDICTION

# %%
x = scaler.transform([[32]])

regressor.predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([86.45529086])

# %%
x = scaler.transform([[101]])

regressor.predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([86.45529086])
